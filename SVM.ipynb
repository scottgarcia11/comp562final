# %% [markdown]
# ## SVM on Leaf Classification Data Set

# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold

leaf = pd.read_csv('train.csv')

# %% [markdown]
# ### Data Preprocessing
#
# Class labels need to be number encoded for fitting with the model.  We additionally need to remove species and id from the dataset so that the model does not fit to those values. We use stratification for splitting the data into training and test sets because of the large number of classes (100) in a relatively small dataset (990 observations)

# %%
leaf = pd.read_csv('train.csv')

le = LabelEncoder().fit(leaf.species) 
labels = le.transform(leaf.species) 
leaf = leaf.drop(['species', 'id'], axis=1)  

X_train, X_test, y_train, y_test = train_test_split(leaf, labels, test_size=0.3, stratify=labels)

X_train.head()
# Out:
#       margin1   margin2   margin3   margin4   margin5   margin6   margin7  \
# 524  0.019531  0.029297  0.041016  0.001953  0.005859  0.021484  0.007812
# 469  0.009766  0.023438  0.029297  0.056641  0.037109  0.013672  0.011719
# 458  0.021484  0.056641  0.005859  0.048828  0.000000  0.128910  0.000000
# 954  0.000000  0.007812  0.023438  0.046875  0.011719  0.000000  0.005859
# 229  0.003906  0.009766  0.066406  0.033203  0.025391  0.000000  0.019531
#
#       margin8   margin9  margin10    ...      texture55  texture56  texture57  \
# 524  0.000000  0.007812  0.013672    ...       0.000000   0.003906   0.008789
# 469  0.000000  0.003906  0.013672    ...       0.000000   0.000000   0.007812
# 458  0.000000  0.007812  0.005859    ...       0.057617   0.000000   0.028320
# 954  0.000000  0.005859  0.013672    ...       0.013672   0.000000   0.022461
# 229  0.005859  0.005859  0.013672    ...       0.000000   0.001953   0.013672
#
#      texture58  texture59  texture60  texture61  texture62  texture63  \
# 524   0.019531   0.012695   0.003906   0.000000   0.009766   0.000000
# 469   0.001953   0.089844   0.000000   0.000000   0.001953   0.020508
# 458   0.000000   0.014648   0.000000   0.000000   0.006836   0.000000
# 954   0.000000   0.017578   0.000000   0.035156   0.000000   0.006836
# 229   0.003906   0.001953   0.001953   0.000000   0.002930   0.000000
#
#      texture64
# 524   0.000977
# 469   0.000000
# 458   0.041992
# 954   0.002930
# 229   0.011719
#
# [5 rows x 192 columns]

# %% [markdown]
# ### Parameter Tuning
#
# First we'll use a grid search to determine the ideal SVM model based on the training data. The tuned parameters are:
# * C: Penalty parameter C of the error term. This is used to regularlize the model and has a tradeoff between a smooth fit and exactly fitting the training data.
# * kernel: kernel type for the algorithm, must be one of ‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’
# * gamma: Kernel coefficient for ‘rbf’, ‘poly’ and ‘sigmoid’. A higher gamma value makes the model fit more to the training data
# * degree: Only used for polynomial SVM. Determines the degree of the polynomial when making the hyperplane

# %%
Cs = [0.001, 0.01, 0.1, 1, 10, 25, 50, 100, 1000]
kernels = ["linear", "rbf", "sigmoid", "poly"]
gammas = [0.001, 0.01, 0.1, 1, 10]
degrees = [2,3,4,5,6] # degree = 1 is identical to linear kernel
#different param dict for each kernel to remove redundancies
param_grid = [{'kernel' : ["linear"] ,'C': Cs},
             {'kernel': ["rbf", "sigmoid"], 'C': Cs, 'gamma': gammas},
             {'kernel' : ["poly"], 'C': Cs, 'gamma': gammas, 'degree': degrees}]
grid_search = GridSearchCV(SVC(), param_grid, cv=5)
grid_search.fit(X_train, y_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid=[{'kernel': ['linear'], 'C': [0.001, 0.01, 0.1, 1, 10, 25, 50, 100, 1000]}, {'kernel': ['rbf', 'sigmoid'], 'C': [0.001, 0.01, 0.1, 1, 10, 25, 50, 100, 1000], 'gamma': [0.001, 0.01, 0.1, 1, 10]}, {'kernel': ['poly'], 'C': [0.001, 0.01, 0.1, 1, 10, 25, 50, 100, 1000], 'gamma': [0.001, 0.01, 0.1, 1, 10], 'degree': [2, 3, 4, 5, 6]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
print("Best parameter set from grid search: ", grid_search.best_params_)
print("\nBest Accuracy: ", grid_search.best_score_, '\n')

for mean, params in zip(grid_search.cv_results_['mean_test_score'], grid_search.cv_results_['params']):
    print("%0.3f for %r" % (mean, params))
# Out:
# Best parameter set from grid search:  {'C': 50, 'kernel': 'linear'}
#
# Best Accuracy:  0.924963924964
#
# 0.788 for {'C': 0.001, 'kernel': 'linear'}
# 0.788 for {'C': 0.01, 'kernel': 'linear'}
# 0.788 for {'C': 0.1, 'kernel': 'linear'}
# 0.788 for {'C': 1, 'kernel': 'linear'}
# 0.851 for {'C': 10, 'kernel': 'linear'}
# 0.902 for {'C': 25, 'kernel': 'linear'}
# 0.925 for {'C': 50, 'kernel': 'linear'}
# 0.925 for {'C': 100, 'kernel': 'linear'}
# 0.924 for {'C': 1000, 'kernel': 'linear'}
# 0.788 for {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.788 for {'C': 0.001, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.788 for {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.788 for {'C': 0.001, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.788 for {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.788 for {'C': 0.001, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.797 for {'C': 0.001, 'gamma': 1, 'kernel': 'rbf'}
# 0.788 for {'C': 0.001, 'gamma': 1, 'kernel': 'sigmoid'}
# 0.830 for {'C': 0.001, 'gamma': 10, 'kernel': 'rbf'}
# 0.726 for {'C': 0.001, 'gamma': 10, 'kernel': 'sigmoid'}
# 0.788 for {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.788 for {'C': 0.01, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.788 for {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.788 for {'C': 0.01, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.788 for {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.788 for {'C': 0.01, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.797 for {'C': 0.01, 'gamma': 1, 'kernel': 'rbf'}
# 0.788 for {'C': 0.01, 'gamma': 1, 'kernel': 'sigmoid'}
# 0.830 for {'C': 0.01, 'gamma': 10, 'kernel': 'rbf'}
# 0.726 for {'C': 0.01, 'gamma': 10, 'kernel': 'sigmoid'}
# 0.788 for {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.788 for {'C': 0.1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.788 for {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.788 for {'C': 0.1, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.788 for {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.788 for {'C': 0.1, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.797 for {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# 0.788 for {'C': 0.1, 'gamma': 1, 'kernel': 'sigmoid'}
# 0.830 for {'C': 0.1, 'gamma': 10, 'kernel': 'rbf'}
# 0.726 for {'C': 0.1, 'gamma': 10, 'kernel': 'sigmoid'}
# 0.788 for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.788 for {'C': 1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.788 for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.788 for {'C': 1, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.788 for {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.788 for {'C': 1, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.798 for {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# 0.788 for {'C': 1, 'gamma': 1, 'kernel': 'sigmoid'}
# 0.876 for {'C': 1, 'gamma': 10, 'kernel': 'rbf'}
# 0.747 for {'C': 1, 'gamma': 10, 'kernel': 'sigmoid'}
# 0.788 for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.788 for {'C': 10, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.788 for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.788 for {'C': 10, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.791 for {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.788 for {'C': 10, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.898 for {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 0.850 for {'C': 10, 'gamma': 1, 'kernel': 'sigmoid'}
# 0.915 for {'C': 10, 'gamma': 10, 'kernel': 'rbf'}
# 0.847 for {'C': 10, 'gamma': 10, 'kernel': 'sigmoid'}
# 0.788 for {'C': 25, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.788 for {'C': 25, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.788 for {'C': 25, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.788 for {'C': 25, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.808 for {'C': 25, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.792 for {'C': 25, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.922 for {'C': 25, 'gamma': 1, 'kernel': 'rbf'}
# 0.905 for {'C': 25, 'gamma': 1, 'kernel': 'sigmoid'}
# 0.915 for {'C': 25, 'gamma': 10, 'kernel': 'rbf'}
# 0.843 for {'C': 25, 'gamma': 10, 'kernel': 'sigmoid'}
# 0.788 for {'C': 50, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.788 for {'C': 50, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.788 for {'C': 50, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.788 for {'C': 50, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.851 for {'C': 50, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.810 for {'C': 50, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.922 for {'C': 50, 'gamma': 1, 'kernel': 'rbf'}
# 0.925 for {'C': 50, 'gamma': 1, 'kernel': 'sigmoid'}
# 0.915 for {'C': 50, 'gamma': 10, 'kernel': 'rbf'}
# 0.844 for {'C': 50, 'gamma': 10, 'kernel': 'sigmoid'}
# 0.788 for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.788 for {'C': 100, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.791 for {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.788 for {'C': 100, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.899 for {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.851 for {'C': 100, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.922 for {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# 0.925 for {'C': 100, 'gamma': 1, 'kernel': 'sigmoid'}
# 0.915 for {'C': 100, 'gamma': 10, 'kernel': 'rbf'}
# 0.848 for {'C': 100, 'gamma': 10, 'kernel': 'sigmoid'}
# 0.791 for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.788 for {'C': 1000, 'gamma': 0.001, 'kernel': 'sigmoid'}
# 0.899 for {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.853 for {'C': 1000, 'gamma': 0.01, 'kernel': 'sigmoid'}
# 0.922 for {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.925 for {'C': 1000, 'gamma': 0.1, 'kernel': 'sigmoid'}
# 0.922 for {'C': 1000, 'gamma': 1, 'kernel': 'rbf'}
# 0.924 for {'C': 1000, 'gamma': 1, 'kernel': 'sigmoid'}
# 0.915 for {'C': 1000, 'gamma': 10, 'kernel': 'rbf'}
# 0.850 for {'C': 1000, 'gamma': 10, 'kernel': 'sigmoid'}
# 0.742 for {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# 0.742 for {'C': 0.001, 'degree': 2, 'gamma': 0.01, 'kernel': 'poly'}
# 0.742 for {'C': 0.001, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# 0.742 for {'C': 0.001, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# 0.742 for {'C': 0.001, 'degree': 2, 'gamma': 10, 'kernel': 'poly'}
# 0.649 for {'C': 0.001, 'degree': 3, 'gamma': 0.001, 'kernel': 'poly'}
# 0.654 for {'C': 0.001, 'degree': 3, 'gamma': 0.01, 'kernel': 'poly'}
# 0.654 for {'C': 0.001, 'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# 0.654 for {'C': 0.001, 'degree': 3, 'gamma': 1, 'kernel': 'poly'}
# 0.654 for {'C': 0.001, 'degree': 3, 'gamma': 10, 'kernel': 'poly'}
# 0.505 for {'C': 0.001, 'degree': 4, 'gamma': 0.001, 'kernel': 'poly'}
# 0.567 for {'C': 0.001, 'degree': 4, 'gamma': 0.01, 'kernel': 'poly'}
# 0.571 for {'C': 0.001, 'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# 0.571 for {'C': 0.001, 'degree': 4, 'gamma': 1, 'kernel': 'poly'}
# 0.571 for {'C': 0.001, 'degree': 4, 'gamma': 10, 'kernel': 'poly'}
# 0.502 for {'C': 0.001, 'degree': 5, 'gamma': 0.001, 'kernel': 'poly'}
# 0.551 for {'C': 0.001, 'degree': 5, 'gamma': 0.01, 'kernel': 'poly'}
# 0.482 for {'C': 0.001, 'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# 0.482 for {'C': 0.001, 'degree': 5, 'gamma': 1, 'kernel': 'poly'}
# 0.488 for {'C': 0.001, 'degree': 5, 'gamma': 10, 'kernel': 'poly'}
# 0.491 for {'C': 0.001, 'degree': 6, 'gamma': 0.001, 'kernel': 'poly'}
# 0.488 for {'C': 0.001, 'degree': 6, 'gamma': 0.01, 'kernel': 'poly'}
# 0.395 for {'C': 0.001, 'degree': 6, 'gamma': 0.1, 'kernel': 'poly'}
# 0.404 for {'C': 0.001, 'degree': 6, 'gamma': 1, 'kernel': 'poly'}
# 0.410 for {'C': 0.001, 'degree': 6, 'gamma': 10, 'kernel': 'poly'}
# 0.742 for {'C': 0.01, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# 0.742 for {'C': 0.01, 'degree': 2, 'gamma': 0.01, 'kernel': 'poly'}
# 0.742 for {'C': 0.01, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# 0.742 for {'C': 0.01, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# 0.742 for {'C': 0.01, 'degree': 2, 'gamma': 10, 'kernel': 'poly'}
# 0.654 for {'C': 0.01, 'degree': 3, 'gamma': 0.001, 'kernel': 'poly'}
# 0.654 for {'C': 0.01, 'degree': 3, 'gamma': 0.01, 'kernel': 'poly'}
# 0.654 for {'C': 0.01, 'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# 0.654 for {'C': 0.01, 'degree': 3, 'gamma': 1, 'kernel': 'poly'}
# 0.657 for {'C': 0.01, 'degree': 3, 'gamma': 10, 'kernel': 'poly'}
# 0.550 for {'C': 0.01, 'degree': 4, 'gamma': 0.001, 'kernel': 'poly'}
# 0.570 for {'C': 0.01, 'degree': 4, 'gamma': 0.01, 'kernel': 'poly'}
# 0.571 for {'C': 0.01, 'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# 0.571 for {'C': 0.01, 'degree': 4, 'gamma': 1, 'kernel': 'poly'}
# 0.577 for {'C': 0.01, 'degree': 4, 'gamma': 10, 'kernel': 'poly'}
# 0.502 for {'C': 0.01, 'degree': 5, 'gamma': 0.001, 'kernel': 'poly'}
# 0.561 for {'C': 0.01, 'degree': 5, 'gamma': 0.01, 'kernel': 'poly'}
# 0.482 for {'C': 0.01, 'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# 0.482 for {'C': 0.01, 'degree': 5, 'gamma': 1, 'kernel': 'poly'}
# 0.494 for {'C': 0.01, 'degree': 5, 'gamma': 10, 'kernel': 'poly'}
# 0.491 for {'C': 0.01, 'degree': 6, 'gamma': 0.001, 'kernel': 'poly'}
# 0.491 for {'C': 0.01, 'degree': 6, 'gamma': 0.01, 'kernel': 'poly'}
# 0.404 for {'C': 0.01, 'degree': 6, 'gamma': 0.1, 'kernel': 'poly'}
# 0.404 for {'C': 0.01, 'degree': 6, 'gamma': 1, 'kernel': 'poly'}
# 0.423 for {'C': 0.01, 'degree': 6, 'gamma': 10, 'kernel': 'poly'}
# 0.742 for {'C': 0.1, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# 0.742 for {'C': 0.1, 'degree': 2, 'gamma': 0.01, 'kernel': 'poly'}
# 0.742 for {'C': 0.1, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# 0.742 for {'C': 0.1, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# 0.746 for {'C': 0.1, 'degree': 2, 'gamma': 10, 'kernel': 'poly'}
# 0.654 for {'C': 0.1, 'degree': 3, 'gamma': 0.001, 'kernel': 'poly'}
# 0.654 for {'C': 0.1, 'degree': 3, 'gamma': 0.01, 'kernel': 'poly'}
# 0.654 for {'C': 0.1, 'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# 0.654 for {'C': 0.1, 'degree': 3, 'gamma': 1, 'kernel': 'poly'}
# 0.677 for {'C': 0.1, 'degree': 3, 'gamma': 10, 'kernel': 'poly'}
# 0.605 for {'C': 0.1, 'degree': 4, 'gamma': 0.001, 'kernel': 'poly'}
# 0.571 for {'C': 0.1, 'degree': 4, 'gamma': 0.01, 'kernel': 'poly'}
# 0.571 for {'C': 0.1, 'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# 0.571 for {'C': 0.1, 'degree': 4, 'gamma': 1, 'kernel': 'poly'}
# 0.622 for {'C': 0.1, 'degree': 4, 'gamma': 10, 'kernel': 'poly'}
# 0.502 for {'C': 0.1, 'degree': 5, 'gamma': 0.001, 'kernel': 'poly'}
# 0.442 for {'C': 0.1, 'degree': 5, 'gamma': 0.01, 'kernel': 'poly'}
# 0.482 for {'C': 0.1, 'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# 0.482 for {'C': 0.1, 'degree': 5, 'gamma': 1, 'kernel': 'poly'}
# 0.551 for {'C': 0.1, 'degree': 5, 'gamma': 10, 'kernel': 'poly'}
# 0.491 for {'C': 0.1, 'degree': 6, 'gamma': 0.001, 'kernel': 'poly'}
# 0.504 for {'C': 0.1, 'degree': 6, 'gamma': 0.01, 'kernel': 'poly'}
# 0.404 for {'C': 0.1, 'degree': 6, 'gamma': 0.1, 'kernel': 'poly'}
# 0.404 for {'C': 0.1, 'degree': 6, 'gamma': 1, 'kernel': 'poly'}
# 0.483 for {'C': 0.1, 'degree': 6, 'gamma': 10, 'kernel': 'poly'}
# 0.742 for {'C': 1, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# 0.742 for {'C': 1, 'degree': 2, 'gamma': 0.01, 'kernel': 'poly'}
# 0.742 for {'C': 1, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# 0.742 for {'C': 1, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# 0.861 for {'C': 1, 'degree': 2, 'gamma': 10, 'kernel': 'poly'}
# 0.654 for {'C': 1, 'degree': 3, 'gamma': 0.001, 'kernel': 'poly'}
# 0.654 for {'C': 1, 'degree': 3, 'gamma': 0.01, 'kernel': 'poly'}
# 0.654 for {'C': 1, 'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# 0.654 for {'C': 1, 'degree': 3, 'gamma': 1, 'kernel': 'poly'}
# 0.847 for {'C': 1, 'degree': 3, 'gamma': 10, 'kernel': 'poly'}
# 0.499 for {'C': 1, 'degree': 4, 'gamma': 0.001, 'kernel': 'poly'}
# 0.571 for {'C': 1, 'degree': 4, 'gamma': 0.01, 'kernel': 'poly'}
# 0.571 for {'C': 1, 'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# 0.571 for {'C': 1, 'degree': 4, 'gamma': 1, 'kernel': 'poly'}
# 0.794 for {'C': 1, 'degree': 4, 'gamma': 10, 'kernel': 'poly'}
# 0.499 for {'C': 1, 'degree': 5, 'gamma': 0.001, 'kernel': 'poly'}
# 0.479 for {'C': 1, 'degree': 5, 'gamma': 0.01, 'kernel': 'poly'}
# 0.482 for {'C': 1, 'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# 0.482 for {'C': 1, 'degree': 5, 'gamma': 1, 'kernel': 'poly'}
# 0.719 for {'C': 1, 'degree': 5, 'gamma': 10, 'kernel': 'poly'}
# 0.491 for {'C': 1, 'degree': 6, 'gamma': 0.001, 'kernel': 'poly'}
# 0.563 for {'C': 1, 'degree': 6, 'gamma': 0.01, 'kernel': 'poly'}
# 0.404 for {'C': 1, 'degree': 6, 'gamma': 0.1, 'kernel': 'poly'}
# 0.404 for {'C': 1, 'degree': 6, 'gamma': 1, 'kernel': 'poly'}
# 0.623 for {'C': 1, 'degree': 6, 'gamma': 10, 'kernel': 'poly'}
# 0.742 for {'C': 10, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# 0.742 for {'C': 10, 'degree': 2, 'gamma': 0.01, 'kernel': 'poly'}
# 0.742 for {'C': 10, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# 0.746 for {'C': 10, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# 0.916 for {'C': 10, 'degree': 2, 'gamma': 10, 'kernel': 'poly'}
# 0.654 for {'C': 10, 'degree': 3, 'gamma': 0.001, 'kernel': 'poly'}
# 0.654 for {'C': 10, 'degree': 3, 'gamma': 0.01, 'kernel': 'poly'}
# 0.654 for {'C': 10, 'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# 0.657 for {'C': 10, 'degree': 3, 'gamma': 1, 'kernel': 'poly'}
# 0.898 for {'C': 10, 'degree': 3, 'gamma': 10, 'kernel': 'poly'}
# 0.567 for {'C': 10, 'degree': 4, 'gamma': 0.001, 'kernel': 'poly'}
# 0.571 for {'C': 10, 'degree': 4, 'gamma': 0.01, 'kernel': 'poly'}
# 0.571 for {'C': 10, 'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# 0.571 for {'C': 10, 'degree': 4, 'gamma': 1, 'kernel': 'poly'}
# 0.880 for {'C': 10, 'degree': 4, 'gamma': 10, 'kernel': 'poly'}
# 0.514 for {'C': 10, 'degree': 5, 'gamma': 0.001, 'kernel': 'poly'}
# 0.483 for {'C': 10, 'degree': 5, 'gamma': 0.01, 'kernel': 'poly'}
# 0.482 for {'C': 10, 'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# 0.482 for {'C': 10, 'degree': 5, 'gamma': 1, 'kernel': 'poly'}
# 0.837 for {'C': 10, 'degree': 5, 'gamma': 10, 'kernel': 'poly'}
# 0.491 for {'C': 10, 'degree': 6, 'gamma': 0.001, 'kernel': 'poly'}
# 0.558 for {'C': 10, 'degree': 6, 'gamma': 0.01, 'kernel': 'poly'}
# 0.404 for {'C': 10, 'degree': 6, 'gamma': 0.1, 'kernel': 'poly'}
# 0.404 for {'C': 10, 'degree': 6, 'gamma': 1, 'kernel': 'poly'}
# 0.799 for {'C': 10, 'degree': 6, 'gamma': 10, 'kernel': 'poly'}
# 0.742 for {'C': 25, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# 0.742 for {'C': 25, 'degree': 2, 'gamma': 0.01, 'kernel': 'poly'}
# 0.742 for {'C': 25, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# 0.766 for {'C': 25, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# 0.916 for {'C': 25, 'degree': 2, 'gamma': 10, 'kernel': 'poly'}
# 0.654 for {'C': 25, 'degree': 3, 'gamma': 0.001, 'kernel': 'poly'}
# 0.654 for {'C': 25, 'degree': 3, 'gamma': 0.01, 'kernel': 'poly'}
# 0.654 for {'C': 25, 'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# 0.658 for {'C': 25, 'degree': 3, 'gamma': 1, 'kernel': 'poly'}
# 0.898 for {'C': 25, 'degree': 3, 'gamma': 10, 'kernel': 'poly'}
# 0.570 for {'C': 25, 'degree': 4, 'gamma': 0.001, 'kernel': 'poly'}
# 0.571 for {'C': 25, 'degree': 4, 'gamma': 0.01, 'kernel': 'poly'}
# 0.571 for {'C': 25, 'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# 0.574 for {'C': 25, 'degree': 4, 'gamma': 1, 'kernel': 'poly'}
# 0.880 for {'C': 25, 'degree': 4, 'gamma': 10, 'kernel': 'poly'}
# 0.514 for {'C': 25, 'degree': 5, 'gamma': 0.001, 'kernel': 'poly'}
# 0.482 for {'C': 25, 'degree': 5, 'gamma': 0.01, 'kernel': 'poly'}
# 0.482 for {'C': 25, 'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# 0.482 for {'C': 25, 'degree': 5, 'gamma': 1, 'kernel': 'poly'}
# 0.837 for {'C': 25, 'degree': 5, 'gamma': 10, 'kernel': 'poly'}
# 0.491 for {'C': 25, 'degree': 6, 'gamma': 0.001, 'kernel': 'poly'}
# 0.495 for {'C': 25, 'degree': 6, 'gamma': 0.01, 'kernel': 'poly'}
# 0.404 for {'C': 25, 'degree': 6, 'gamma': 0.1, 'kernel': 'poly'}
# 0.404 for {'C': 25, 'degree': 6, 'gamma': 1, 'kernel': 'poly'}
# 0.802 for {'C': 25, 'degree': 6, 'gamma': 10, 'kernel': 'poly'}
# 0.742 for {'C': 50, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# 0.742 for {'C': 50, 'degree': 2, 'gamma': 0.01, 'kernel': 'poly'}
# 0.742 for {'C': 50, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# 0.818 for {'C': 50, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# 0.916 for {'C': 50, 'degree': 2, 'gamma': 10, 'kernel': 'poly'}
# 0.654 for {'C': 50, 'degree': 3, 'gamma': 0.001, 'kernel': 'poly'}
# 0.654 for {'C': 50, 'degree': 3, 'gamma': 0.01, 'kernel': 'poly'}
# 0.654 for {'C': 50, 'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# 0.664 for {'C': 50, 'degree': 3, 'gamma': 1, 'kernel': 'poly'}
# 0.898 for {'C': 50, 'degree': 3, 'gamma': 10, 'kernel': 'poly'}
# 0.571 for {'C': 50, 'degree': 4, 'gamma': 0.001, 'kernel': 'poly'}
# 0.571 for {'C': 50, 'degree': 4, 'gamma': 0.01, 'kernel': 'poly'}
# 0.571 for {'C': 50, 'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# 0.576 for {'C': 50, 'degree': 4, 'gamma': 1, 'kernel': 'poly'}
# 0.880 for {'C': 50, 'degree': 4, 'gamma': 10, 'kernel': 'poly'}
# 0.564 for {'C': 50, 'degree': 5, 'gamma': 0.001, 'kernel': 'poly'}
# 0.483 for {'C': 50, 'degree': 5, 'gamma': 0.01, 'kernel': 'poly'}
# 0.482 for {'C': 50, 'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# 0.485 for {'C': 50, 'degree': 5, 'gamma': 1, 'kernel': 'poly'}
# 0.837 for {'C': 50, 'degree': 5, 'gamma': 10, 'kernel': 'poly'}
# 0.491 for {'C': 50, 'degree': 6, 'gamma': 0.001, 'kernel': 'poly'}
# 0.434 for {'C': 50, 'degree': 6, 'gamma': 0.01, 'kernel': 'poly'}
# 0.404 for {'C': 50, 'degree': 6, 'gamma': 0.1, 'kernel': 'poly'}
# 0.404 for {'C': 50, 'degree': 6, 'gamma': 1, 'kernel': 'poly'}
# 0.802 for {'C': 50, 'degree': 6, 'gamma': 10, 'kernel': 'poly'}
# 0.742 for {'C': 100, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# 0.742 for {'C': 100, 'degree': 2, 'gamma': 0.01, 'kernel': 'poly'}
# 0.742 for {'C': 100, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# 0.861 for {'C': 100, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# 0.916 for {'C': 100, 'degree': 2, 'gamma': 10, 'kernel': 'poly'}
# 0.654 for {'C': 100, 'degree': 3, 'gamma': 0.001, 'kernel': 'poly'}
# 0.654 for {'C': 100, 'degree': 3, 'gamma': 0.01, 'kernel': 'poly'}
# 0.654 for {'C': 100, 'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# 0.677 for {'C': 100, 'degree': 3, 'gamma': 1, 'kernel': 'poly'}
# 0.898 for {'C': 100, 'degree': 3, 'gamma': 10, 'kernel': 'poly'}
# 0.570 for {'C': 100, 'degree': 4, 'gamma': 0.001, 'kernel': 'poly'}
# 0.571 for {'C': 100, 'degree': 4, 'gamma': 0.01, 'kernel': 'poly'}
# 0.571 for {'C': 100, 'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# 0.577 for {'C': 100, 'degree': 4, 'gamma': 1, 'kernel': 'poly'}
# 0.880 for {'C': 100, 'degree': 4, 'gamma': 10, 'kernel': 'poly'}
# 0.551 for {'C': 100, 'degree': 5, 'gamma': 0.001, 'kernel': 'poly'}
# 0.482 for {'C': 100, 'degree': 5, 'gamma': 0.01, 'kernel': 'poly'}
# 0.482 for {'C': 100, 'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# 0.488 for {'C': 100, 'degree': 5, 'gamma': 1, 'kernel': 'poly'}
# 0.837 for {'C': 100, 'degree': 5, 'gamma': 10, 'kernel': 'poly'}
# 0.491 for {'C': 100, 'degree': 6, 'gamma': 0.001, 'kernel': 'poly'}
# 0.374 for {'C': 100, 'degree': 6, 'gamma': 0.01, 'kernel': 'poly'}
# 0.404 for {'C': 100, 'degree': 6, 'gamma': 0.1, 'kernel': 'poly'}
# 0.405 for {'C': 100, 'degree': 6, 'gamma': 1, 'kernel': 'poly'}
# 0.802 for {'C': 100, 'degree': 6, 'gamma': 10, 'kernel': 'poly'}
# 0.742 for {'C': 1000, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# 0.742 for {'C': 1000, 'degree': 2, 'gamma': 0.01, 'kernel': 'poly'}
# 0.746 for {'C': 1000, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# 0.916 for {'C': 1000, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# 0.916 for {'C': 1000, 'degree': 2, 'gamma': 10, 'kernel': 'poly'}
# 0.654 for {'C': 1000, 'degree': 3, 'gamma': 0.001, 'kernel': 'poly'}
# 0.654 for {'C': 1000, 'degree': 3, 'gamma': 0.01, 'kernel': 'poly'}
# 0.654 for {'C': 1000, 'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# 0.847 for {'C': 1000, 'degree': 3, 'gamma': 1, 'kernel': 'poly'}
# 0.898 for {'C': 1000, 'degree': 3, 'gamma': 10, 'kernel': 'poly'}
# 0.571 for {'C': 1000, 'degree': 4, 'gamma': 0.001, 'kernel': 'poly'}
# 0.571 for {'C': 1000, 'degree': 4, 'gamma': 0.01, 'kernel': 'poly'}
# 0.571 for {'C': 1000, 'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# 0.622 for {'C': 1000, 'degree': 4, 'gamma': 1, 'kernel': 'poly'}
# 0.880 for {'C': 1000, 'degree': 4, 'gamma': 10, 'kernel': 'poly'}
# 0.561 for {'C': 1000, 'degree': 5, 'gamma': 0.001, 'kernel': 'poly'}
# 0.482 for {'C': 1000, 'degree': 5, 'gamma': 0.01, 'kernel': 'poly'}
# 0.482 for {'C': 1000, 'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# 0.494 for {'C': 1000, 'degree': 5, 'gamma': 1, 'kernel': 'poly'}
# 0.837 for {'C': 1000, 'degree': 5, 'gamma': 10, 'kernel': 'poly'}
# 0.488 for {'C': 1000, 'degree': 6, 'gamma': 0.001, 'kernel': 'poly'}
# 0.395 for {'C': 1000, 'degree': 6, 'gamma': 0.01, 'kernel': 'poly'}
# 0.404 for {'C': 1000, 'degree': 6, 'gamma': 0.1, 'kernel': 'poly'}
# 0.410 for {'C': 1000, 'degree': 6, 'gamma': 1, 'kernel': 'poly'}
# 0.802 for {'C': 1000, 'degree': 6, 'gamma': 10, 'kernel': 'poly'}

# %%
grid_search.best_params_
# Out:
# {'C': 50, 'kernel': 'linear'}

# %%
svm = SVC(C=50, kernel="linear", probability=True)
svm.fit(X_train, y_train)
predictions = svm.predict(X_test)

accuracy_score(predictions, y_test)
# Out:
# 0.94612794612794615

# %% [markdown]
# ### Conclusion
# Linear SVM with high cost parameters were shown to be the best, topping >90% accuracy whenever C>=25.  C=50 had the best cross-validation acurracy, and a test accuracy of 94.6%.  Likewise, rbf and sigmoid kernels with high cost parameters also faired exceedlingly well on the training data. Polynomial kernels faired poorly outside of degree = 2 with high values for C and gamma.
